# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# đọc file
csv1 = pd.read_csv('AdvWorksCusts.csv')
csv2 = pd.read_csv('AW_AveMonthSpend.csv')
csv3 = pd.read_csv('AW_BikeBuyer.csv')

# Xóa các dòng trùng nhau trong dataframe
csv1 = csv1.drop_duplicates('CustomerID', 'last')
csv2 = csv2.drop_duplicates('CustomerID', 'last')
csv3 = csv3.drop_duplicates('CustomerID', 'last')

# Nối các dataframe lại thành 1 bảng theo trường CustomerID
csv = csv1.merge(csv2, on = 'CustomerID')
csv = csv.merge(csv3, on = 'CustomerID')

# %%
# Tìm các đối tượng bị thiếu
def find_missing_value(csv, missing_char):
    for col in csv.columns:
        if csv[col].dtype == object:
            count = [1 for x in csv[col] if x is missing_char]
            print (col + ' ' + str(np.sum(count)))
find_missing_value(csv, np.nan)

# Các trường MiddleName, Suffix, AddressLine2, Title có nhiều giá trị nan nên sẽ bị xóa bỏ
csv = csv.drop(['MiddleName','Suffix','AddressLine2','Title'], axis=1)

# Các trường ID, FirstName, LastName, PhoneNumber không giúp ích cho việc phân loại, sẽ bị xóa
csv = csv.drop(['CustomerID','FirstName','LastName','PhoneNumber'], axis=1)
# Out:
# Title 16316
# FirstName 0.0
# MiddleName 6951
# LastName 0.0
# Suffix 16402
# AddressLine1 0.0
# AddressLine2 16131
# City 0.0
# StateProvinceName 0.0
# CountryRegionName 0.0
# PostalCode 0.0
# PhoneNumber 0.0
# BirthDate 0.0
# Education 0.0
# Occupation 0.0
# Gender 0.0
# MaritalStatus 0.0

# %%
# Tạo 1 hàm tìm hiểu số trường hợp xảy ra của các biến dạng phân loại
# 1 biến phân loại có thể có bao nhiêu giá trị, các giá trị đó xuất hiện bao nhiêu lần 
# Từ đó quyết định có nên giữ biến đó không
def count_case_classification_variable(csv, list_columns):
    for col in list_columns:
        print (col)
        print (csv[col].count())
        print (csv[col].nunique())
        print (csv[col].value_counts())
        print (csv[[col, 'BikeBuyer']].groupby(col).sum().sort_values('BikeBuyer', ascending = False))
        print ("-" * 60)
list_columns = ['AddressLine1','City','StateProvinceName','CountryRegionName','PostalCode','BirthDate','Education','Occupation','Gender','MaritalStatus']
count_case_classification_variable(csv, list_columns)
# Out:
# AddressLine1
# 16404
# 11874
# Attaché de Presse                  15
# Midi-Couleurs                      15
# 6, route de Marseille              11
# 88, avenue de l´ Union Centrale    10
# Im Himmelsweg 89                   10
# Postfach 22 99 99                   9
# 11, quai de l´ Iton                 8
# Helsenbergbogen 6                   8
# 2, route de Marseille               8
# 11, avenue du Président-Kennedy     7
# 68, avenue de l´ Union Centrale     7
# Postfach 55 00 00                   7
# Heidestieg Straße 8664              7
# 84, avenue des Ternes               6
# 33, place de la République          6
# 44, rue du Départ                   6
# Hauptstr 2929                       6
# 8, rue des Vendangeurs              6
# Werftstr 54                         6
# Heiderweg 4982                      6
# Residenz Straße 944                 6
# 8, rue de l´Avenir                  6
# 1, rue de la Centenaire             6
# Kappellweg 242                      5
# 5024 Euclid Avenue                       0
# 5024 Countrywood Ct.                     0
# 5022 Euclid Ave.                         0
# Zur Lindung 787                          0
#
# [11874 rows x 1 columns]
# ------------------------------------------------------------
# City
# 16404
# 267
# London              379
# Paris               341
# Beaverton           190
# Burien              188
# Chula Vista         185
# Concord             183
# Bellingham          183
# Berkeley            177
# Burbank             174
# Beverly Hills       170
# Cliffside           169
# Burlingame          166
# Bremerton           165
# Bellflower          164
# Berlin              159
# Colma               150
# Coronado            118
# York                104
# Shawnee             102
# Hamburg             101
# Cranbourne          101
# Downey              100
# Caloundra            98
# Geelong              97
# Sydney               97
# El Cajon             97
# Goulburn             96
# Brisbane             96
# Hervey Bay           95
# Sunbury              94
#                    ...
# Braintree             1
# Baytown               1
# Branson               1
# Chehalis              1
# Bountiful             1
# Carol Stream          1
# Charlotte             1
# Clay                  1
# Casper                1
# Cerritos              1
# Bellevue              1
# City Of Commerce      1
# College Station       1
# Cheektowaga           1
# Biloxi                1
# Canoga Park           1
# Barstow               1
# Bradenton             1
# Sammamish             1
# Clarkston             1
# Chantilly             1
# Cedar City            1
# Campbellsville        1
# Bluffton              1
# Carrollton            1
# Byron                 1
# Clearwater            1
# Central Valley        1
# Newport Hills         1
# Branch                1
# Name: City, Length: 267, dtype: int64
#                    BikeBuyer
# City
# London                   149
# Paris                    102
# Beaverton                 59
# Chula Vista               59
# Bellflower                59
# Cliffside                 59
# Concord                   58
# Bellingham                58
# Bremerton                 57
# Beverly Hills             57
# Burien                    53
# Colma                     51
# Berlin                    49
# Burbank                   48
# Burlingame                47
# Cranbourne                44
# Berkeley                  43
# Rockhampton               42
# Goulburn                  40
# Geelong                   40
# Coronado                  40
# Townsville                40
# Warrnambool               39
# Sydney                    39
# Hobart                    39
# Brisbane                  37
# Wollongong                37
# Yakima                    36
# Darlinghurst              36
# Port Macquarie            36
# ...                      ...
# Camarillo                  1
# Byron                      1
# Casper                     1
# Bothell                    1
# Branson                    1
# Citrus Heights             1
# Sammamish                  1
# Bradenton                  0
# Basingstoke Hants          0
# Campbellsville             0
# Baytown                    0
# Newport Hills              0
# Bell Gardens               0
# Cerritos                   0
# Columbus                   0
# Carol Stream               0
# Bluffton                   0
# Carrollton                 0
# Bellevue                   0
# Biloxi                     0
# Clearwater                 0
# Clarkston                  0
# Cedar City                 0
# Barstow                    0
# Branch                     0
# Braintree                  0
# Clackamas                  0
# Cedar Park                 0
# Central Valley             0
# Canoga Park                0
#
# [267 rows x 1 columns]
# ------------------------------------------------------------
# StateProvinceName
# 16404
# 51
# California             3948
# Washington             2017
# England                1709
# British Columbia       1388
# New South Wales        1376
# Oregon                  934
# Victoria                801
# Queensland              713
# Saarland                388
# Nordrhein-Westfalen     362
# Seine (Paris)           341
# Hessen                  334
# Hamburg                 268
# Seine Saint Denis       255
# Nord                    247
# South Australia         212
# Bayern                  198
# Hauts de Seine          168
# Yveline                 149
# Essonne                 131
# Tasmania                 92
# 1965-09-04          5
# 1966-11-25          5
# 1972-05-28          5
# ...               ...
# 1966-06-22          0
# 1949-10-06          0
# 1949-10-04          0
# 1949-10-02          0
# 1949-09-23          0
# 1966-06-07          0
# 1966-06-08          0
# 1949-09-15          0
# 1949-09-14          0
# 1949-09-13          0
# 1966-06-16          0
# 1966-06-19          0
# 1966-06-20          0
# 1949-08-27          0
# 1966-06-23          0
# 1949-07-19          0
# 1949-08-26          0
# 1949-08-25          0
# 1949-08-24          0
# 1949-08-22          0
# 1949-08-20          0
# 1949-08-17          0
# 1949-08-16          0
# 1949-08-13          0
# 1949-08-07          0
# 1949-08-03          0
# 1949-07-25          0
# 1966-07-17          0
# 1949-07-22          0
# 1910-08-13          0
#
# [7896 rows x 1 columns]
# ------------------------------------------------------------
# Education
# 16404
# 5
# Bachelors              4758
# Partial College        4451
# High School            2944
# Graduate Degree        2851
# Partial High School    1400
# Name: Education, dtype: int64
#                      BikeBuyer
# Education
# Bachelors                 1871
# Partial College           1507
# High School                897
# Graduate Degree            855
# Partial High School        325
# ------------------------------------------------------------
# Occupation
# 16404
# 5
# Professional      4922
# Skilled Manual    4038
# Management        2718
# Clerical          2597
# Manual            2129
# Name: Occupation, dtype: int64
#                 BikeBuyer
# Occupation
# Professional         2184
# Skilled Manual       1135
# Management           1016
# Clerical              616
# Manual                504
# ------------------------------------------------------------
# Gender
# 16404
# 2
# M    8290
# F    8114
# Name: Gender, dtype: int64
#         BikeBuyer
# Gender
# M            3222
# F            2233
# ------------------------------------------------------------
# MaritalStatus
# 16404
# 2
# M    8852
# S    7552
# Name: MaritalStatus, dtype: int64
#                BikeBuyer
# MaritalStatus
# S                   3256
# M                   2199
# ------------------------------------------------------------

# %%
# Về trường AddressLine1, ta có thể gộp những khu phố vào 1 nhóm
# Bỏ các số nhà và giữ lại tên khu phố họ sống 
tmp = []
for address in csv['AddressLine1']:
    c = [x for x in address if x not in ['1','2','3','4','5','6','7','8','9','0',',','.']]
    tmp += [''.join(c)]
csv['AddressLine1'] = tmp

# Kiểm tra lại dữ liệu sau khi 
#print (csv['AddressLine1'].value_counts())
#print (csv[['AddressLine1','BikeBuyer']].groupby('AddressLine1').mean().sort_values('BikeBuyer', ascending = False))
# Do sau khi ghép dữ liệu, trường AddressLine1 còn khá nhiều giá trị khác nhau, đồng thời mỗi nhóm phố 
# không có nhóm phố nào nổi bật (Mua nhiều xe hơn hẳn các phố còn lại). Do đó ta sẽ loại trường AddressLine1
csv = csv.drop('AddressLine1', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-31c6ceacc79d> in <module>
#      12 # Do sau khi ghép dữ liệu, trường AddressLine1 còn khá nhiều giá trị khác nhau, đồng thời mỗi nhóm phố
#      13 # không có nhóm phố nào nổi bật (Mua nhiều xe hơn hẳn các phố còn lại). Do đó ta sẽ loại trường AddressLine1
# ---> 14 csv = csv.drop('AddressLine1')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['AddressLine1'] not found in axis"

# %%
# Thay trường BirthDate bằng Age
year_of_birth = [x[:4] for x in csv['BirthDate']]
csv['Age'] = [1998 - int(x) for x in year_of_birth]

tmp = []
for x in csv['Age']:
    if x < 25: tmp += ['<25']
    elif x >= 25 and x < 45: tmp += ['25,45']
    elif x >= 45 and x < 55: tmp += ['45,55']
    else: tmp += ['>=55']
csv['Age'] = tmp
csv = csv.drop('BirthDate', axis = 1)

# %%
# Kiểm tra lại số liệu trước khi tiến hành xây dựng học máy 
list_columns = ['AddressLine1','City','StateProvinceName','CountryRegionName','PostalCode','Age','Education','Occupation','Gender','MaritalStatus']
count_case_classification_variable(csv, list_columns)
# Out:
# AddressLine1
# 16404
# 3427
# Postfach                        77
#  route de Marseille             58
#  avenue de l´ Union Centrale    37
#  avenue de la Gare              36
# Am Gallberg                     34
#  rue de Cambrai                 32
#  rue de la Centenaire           30
# Buergermeister-ulrich-str       30
#  Pine Creek Way                 25
#  rue Villedo                    25
#  St George Dr                   24
#  Detroit Ave                    22
#  avenue des Laurentides         22
#  allée des Princes              22
#  rue Philibert-Delorme          22
#  rue des Ecoles                 21
#  rue de Berri                   21
#  quai de Grenelle               20
#  Mt Hood Circle                 20
#  impasse Ste-Madeleine          20
#  rue Jean Mermoz                20
#  place Beaubernard              20
#  rue de l´Avenir                20
#  avenue Reille                  20
#  rue de l´Esplanade             20
#  rue Mazagran                   20
#  rue Pierre-Demoulin            20
#  Pinehurst Court                19
#  boulevard Tremblay             19
#  cours Mirabeau                 19
#                                 ..
#  Glen Ellen Court                1
#  Glen Arms Dr                    1
#  Melrose Pl                      1
#  Gregory Lane                    1
#  Lafayette Drive                 1
#  Aloe Vera Rd                    1
#  Babbe St                        1
#  Tank Drive                      1
#  Diehl Way                       1
#  Gem Court                       1
#  Hames Drive                     1
#  Bouncing                        1
#  Mellowood St                    1
#  Bird Dr                         1
#  Gabriela                        1
#  Homestead Avenue                1
#  Huron Dr                        1
#  Thornhill Pl                    1
#  Gill Drive                      1
#  Live Oak Dr                     1
#  Shadow Court                    1
#  Oak Wood Court                  1
#  Mt Tooth Pl                     1
#  Bay View Dr                     1
#  Akyn Rock Dr                    1
#  Fish Drive                      1
#  Surf Drive                      1
#  Holly Oak Drive                 1
#  Geranium Court                  1
#  Mission Blvd                    1
# Name: AddressLine1, Length: 3427, dtype: int64
#                               BikeBuyer
# AddressLine1
# Postfach                             28
#  route de Marseille                  17
# Buergermeister-ulrich-str            16
#  avenue de l´ Union Centrale         14
# Am Gallberg                          11
#  avenue de la Gare                   10
#  Mt Washington Way                   10
#  rue des Rosiers                     10
# Bundesallee                          10
# Hochstr                              10
# Nollendorfplatz                      10
#  rue Saint Denis                     10
#  First Ave                            9
#  rue de Cambrai                       9
# Winter der Böck                       9
#  rue de la Centenaire                 9
#  avenue des Ternes                    9
# Zollhof                               9
#  rue des Ecoles                       8
# Erftplatz                             8
# Zollstr                               8
#  rue du Puits Dixme                   8
# Westheimer Straße                     8
# Rehstr                                8
#  rue de l´Avenir                      8
# Hansaallee                            8
#  rue de Bas Marin                     8
#  Pinehurst Court                      8
#  rue Marbeuf                          8
# Erlenweg                              8
# ...                                 ...
#  E Leland                             0
#  E Leland Rd                          0
#  Bermad Dr                            0
#  Peterson Place                       0
#  E Nd Street                          0
#  Perry Way                            0
#  Pepperidge Place                     0
#  E Watson Court                       0
#  Pine Valley Rd                       0
#  Dumbarton Street                     0
#  Ponderosa Way                        0
#  Dumbarton St                         0
#  Poncho Street                        0
#  Bentley Street                       0
#  Pomar Way                            0
#  Benton St                            0
#  Plymouth Drive                       0
#  Pleasant Hill Road                   0
#  Apple Court                          0
#  Plaza Rosa                           0
#  Plaza Del Rio                        0
#  Placer Dr                            0
#  Pinto                                0
#  Pinon Dr                             0
#  Pinnacle Drive                       0
#  Pinnacle Dr                          0
#  Dumbarton Dr                         0
#  Pineview Lane                        0
#  Pinetree Ct                          0
#  Buchanan Ct                          0
#
# [3427 rows x 1 columns]
# ------------------------------------------------------------
# City
# 16404
# 267
# London              379
# Paris               341
# Beaverton           190
# Burien              188
# Chula Vista         185
# Bellingham          183
# Concord             183
# Berkeley            177
# Burbank             174
# Beverly Hills       170
# Cliffside           169
# Burlingame          166
# Bremerton           165
# Bellflower          164
# Berlin              159
# Colma               150
# Coronado            118
# York                104
# Shawnee             102
# Cranbourne          101
# Hamburg             101
# Downey              100
# Caloundra            98
# Sydney               97
# El Cajon             97
# Geelong              97
# Goulburn             96
# Brisbane             96
# Hervey Bay           95
# Langford             94
#                    ...
# Branson               1
# Clay                  1
# Baytown               1
# Citrus Heights        1
# Chantilly             1
# Chehalis              1
# Branch                1
# Cheektowaga           1
# Cerritos              1
# Central Valley        1
# Charlotte             1
# Sammamish             1
# Cedar City            1
# Newport Hills         1
# College Station       1
# Bradenton             1
# Casper                1
# Byron                 1
# Clarkston             1
# City Of Commerce      1
# Carrollton            1
# Canoga Park           1
# Cedar Park            1
# Campbellsville        1
# Bluffton              1
# Bellevue              1
# Barstow               1
# Carol Stream          1
# Bountiful             1
# Braintree             1
# Name: City, Length: 267, dtype: int64
#                    BikeBuyer
# City
# London                   149
# Paris                    102
# Beaverton                 59
# Chula Vista               59
# Bellflower                59
# Cliffside                 59
# Concord                   58
# Bellingham                58
# Bremerton                 57
# Beverly Hills             57
# Burien                    53
# Colma                     51
# Berlin                    49
# Burbank                   48
# Burlingame                47
# Cranbourne                44
# Berkeley                  43
# Rockhampton               42
# Goulburn                  40
# Geelong                   40
# Coronado                  40
# Townsville                40
# Warrnambool               39
# Sydney                    39
# Hobart                    39
# Brisbane                  37
# Wollongong                37
# Yakima                    36
# Darlinghurst              36
# Port Macquarie            36
# ...                      ...
# Camarillo                  1
# Byron                      1
# Casper                     1
# Bothell                    1
# Branson                    1
# Citrus Heights             1
# Sammamish                  1
# Bradenton                  0
# Basingstoke Hants          0
# Campbellsville             0
# Baytown                    0
# Newport Hills              0
# Bell Gardens               0
# V8Y 1L1       169
# 94010         166
# 98312         165
# 90706         164
# V7L 4J4       163
# 94014         150
# 2036          141
# 92118         118
# 3977          101
# 90241         100
# 4551           98
# 3220           97
# 92020          97
# 1002           97
# 4000           96
# 2580           96
# 4655           95
# 99362          94
# 3429           94
# 4810           94
#              ...
# 90040           1
# 77840           1
# 95610           1
# 55056           1
# 39530           1
# 34205           1
# 90703           1
# 2184            1
# 28202           1
# 98006           1
# 65616           1
# 42718           1
# 97015           1
# 33755           1
# 97015-6403      1
# 43215           1
# 29910           1
# 30021           1
# 44214           1
# 10917           1
# 35203           1
# 98004           1
# 84720           1
# 90201           1
# 98532           1
# 31901           1
# 91303           1
# 20151           1
# 78613           1
# 92311           1
# Name: PostalCode, Length: 321, dtype: int64
#             BikeBuyer
# PostalCode
# 91950              62
# 91910              59
# 97005              59
# 90706              59
# V8Y 1L1            59
# 94519              58
# 98225              58
# 90210              57
# V7L 4J4            57
# 98312              57
# V9                 54
# 98168              53
# 94014              51
# 91502              48
# 94010              47
# 2036               45
# 3977               44
# 94704              43
# 4700               42
# 2580               40
# 92118              40
# 3220               40
# 4810               40
# 7001               39
# 1002               39
# 3280               39
# 4000               37
# 2500               37
# 2010               36
# 2444               36
# ...               ...
# 98074               1
# 95610               1
# 93010               1
# 20151               1
# 97015-6403          0
# 98004               0
# 98006               0
# 33755               0
# 39530               0
# 35203               0
# 34205               0
# 31901               0
# 30021               0
# 97015               0
# 77520               0
# 42718               0
# 43215               0
# 44214               0
# 10917               0
# 92311               0
# 2184                0
# 55056               0
# 91303               0
# 60188               0
# 90703               0
# 90201               0
# RG24 8PL            0
# 84720               0
# 78613               0
# 29910               0
#
# [321 rows x 1 columns]
# ------------------------------------------------------------
# Age
# 16404
# 4
# 25,45    10118
# 45,55     2601
# <25       2453
# >=55      1232
# Name: Age, dtype: int64
#        BikeBuyer
# Age
# 25,45       4264
# 45,55        576
# <25          555
# >=55          60
# ------------------------------------------------------------
# Education
# 16404
# 5
# Bachelors              4758
# Partial College        4451
# High School            2944
# Graduate Degree        2851
# Partial High School    1400
# Name: Education, dtype: int64
#                      BikeBuyer
# Education
# Bachelors                 1871
# Partial College           1507
# High School                897
# Graduate Degree            855
# Partial High School        325
# ------------------------------------------------------------
# Occupation
# 16404
# 5
# Professional      4922
# Skilled Manual    4038
# Management        2718
# Clerical          2597
# Manual            2129
# Name: Occupation, dtype: int64
#                 BikeBuyer
# Occupation
# Professional         2184
# Skilled Manual       1135
# Management           1016
# Clerical              616
# Manual                504
# ------------------------------------------------------------
# Gender
# 16404
# 2
# M    8290
# F    8114
# Name: Gender, dtype: int64
#         BikeBuyer
# Gender
# M            3222
# F            2233
# ------------------------------------------------------------
# MaritalStatus
# 16404
# 2
# M    8852
# S    7552
# Name: MaritalStatus, dtype: int64
#                BikeBuyer
# MaritalStatus
# S                   3256
# M                   2199
# ------------------------------------------------------------

# %%
csv.to_csv('CSV.csv')
